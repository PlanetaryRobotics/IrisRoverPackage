# %% [markdown]
# ## EM4 Build Up in MoonYard for SCS Demo (11/29/2023) - Cam 0 Quick Frame

# %%
from typing import Final
TEST_NAME: Final = "img_EM4_SCS_MY_test_img_cam0"
stream_via_ipc_first: bool = False
LINE_WIDTH: Final = 6 * 512  # DLing all pages in a line in case of shift (extra space doesn't matter much when compressed)

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
# Load scripting environment:
from scripts.testing.ipc_demo.image_builder_demo import *
# Out:
# environ({'COMMAND_MODE': 'unix2003', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': '/Users/connorcolombo/opt/anaconda3/bin/conda', 'CONDA_PREFIX': '/Users/connorcolombo/opt/anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': '/Users/connorcolombo/opt/anaconda3/bin/python', 'CONDA_SHLVL': '1', 'DISPLAY': '/private/tmp/com.apple.launchd.iPas8YVxou/org.xquartz:0', 'HOME': '/Users/connorcolombo', 'LOGNAME': 'connorcolombo', 'LaunchInstanceID': 'D52A988B-9549-442E-B2CC-A148281AC281', 'MallocNanoZone': '0', 'NVM_DIR': '/Users/connorcolombo/.nvm', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'PATH': '/Users/connorcolombo/.pyenv/versions/3.10.8/envs/py_irisbackendv3/bin:/Users/connorcolombo/.nvm/versions/node/v18.10.0/bin:/Users/connorcolombo/opt/anaconda3/bin:/Users/connorcolombo/.pyenv/bin:/Users/connorcolombo/.pyenv/plugins/pyenv-virtualenv/shims:/Users/connorcolombo/.pyenv/shims:/Users/connorcolombo/.pyenv/bin:/Users/connorcolombo/.pyenv/bin:/Users/connorcolombo/opt/anaconda3/bin:/Users/connorcolombo/opt/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/Library/Frameworks/Python.framework/Versions/3.8/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/go/bin:/Applications/Pololu Jrk G2.app/Contents/MacOS:/opt/X11/bin:/Library/Apple/usr/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Users/connorcolombo/.pyenv/plugins/pyenv-virtualenv/shims:/Users/connorcolombo/.pyenv/bin', 'PWD': '/', 'PYENV_ROOT': '/Users/connorcolombo/.pyenv', 'PYENV_SHELL': 'bash', 'PYENV_VIRTUALENV_INIT': '1', 'SECURITYSESSIONID': '186a4', 'SHELL': '/bin/zsh', 'SHLVL': '1', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.aDfdYPAp0q/Listeners', 'TMPDIR': '/var/folders/44/s4c635957kj582ykvhndm9w00000gn/T/', 'USER': 'connorcolombo', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': '/Users/connorcolombo/Library/Application Support/Code/CachedData/1a5daa3a0231a0fbba4f14db7ec463cf99d7768e', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': '/', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '/Users/connorcolombo/Library/Application Support/Code/1.84-main.sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-us","osLocale":"en-us","availableLanguages":{},"_languagePackSupport":true}', 'VSCODE_PID': '524', 'XPC_FLAGS': '0x0', 'XPC_SERVICE_NAME': '0', '_': '/Users/connorcolombo/.pyenv/versions/3.10.8/envs/py_irisbackendv3/bin/python', '__CFBundleIdentifier': 'com.microsoft.VSCode', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'ELECTRON_RUN_AS_NODE': '1', 'DEBUG': 'WARN', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': 'true', 'WALLABY_PRODUCTION': 'true', 'VSCEXT_TELEMETRY_ID': '81fcfc2a-1443-4565-91cf-02284d4db74f', 'VSCEXT_PROVIDE_FULLSTACK_ACTION': 'true', 'VSCEXT_UTM_SOURCE': 'vscode', 'VSCEXT_EXHORT_DEV_MODE': 'false', 'VSCEXT_EXHORT_SNYK_TOKEN': '', 'VSCEXT_MATCH_MANIFEST_VERSIONS': 'true', 'VSCEXT_EXHORT_MVN_PATH': 'mvn', 'VSCEXT_EXHORT_NPM_PATH': 'npm', 'VSCEXT_EXHORT_GO_PATH': 'go', 'VSCEXT_EXHORT_PYTHON3_PATH': 'python3', 'VSCEXT_EXHORT_PIP3_PATH': 'pip3', 'VSCEXT_EXHORT_PYTHON_PATH': 'python', 'VSCEXT_EXHORT_PIP_PATH': 'pip', 'VSCODE_L10N_BUNDLE_LOCATION': '', 'PLATFORMIO_CALLER': 'vscode', 'LC_ALL': 'en_US.UTF-8', 'PLATFORMIO_IDE': '3.3.1', 'PLATFORMIO_PATH': '/Users/connorcolombo/.platformio/penv/bin:/Users/connorcolombo/.platformio/penv:/Users/connorcolombo/.platformio/python3/bin:/Users/connorcolombo/.pyenv/bin:/Users/connorcolombo/opt/anaconda3/bin:/Users/connorcolombo/opt/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/Library/Frameworks/Python.framework/Versions/3.8/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/go/bin:/Applications/Pololu Jrk G2.app/Contents/MacOS:/opt/X11/bin:/Library/Apple/usr/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Users/connorcolombo/.pyen ...
# {'IP': '127.0.0.1', 'SESSION_KEY': 'test-session-key', 'app_name': 'IpcApp'}
# WARNING: No IPv4 address found on anpi0 !
# WARNING: No IPv4 address found on anpi1 !
# WARNING: more No IPv4 address found on anpi2 !
# 2023-11-29 12:10:47: INFO     Successfully Loaded 22 Modules with 77 Commands, 188 Channels, and 92 Events from ./out/DataStandardsCache/IBv3_datastandards_01HGDT31VWVBAR20ETNHXYSGQB.dsc .
# 2023-11-29 12:10:47: NOTICE   IRIS Lunar Rover - FileBuilderDemo - IPC App Started
# 2023-11-29 12:10:47: VERBOSE  Using default binding scheme (`bind=False`) for `socket_type=<SocketType.SUBSCRIBER: 3>`.
# 2023-11-29 12:10:47: INFO     Created a `SocketType.SUBSCRIBER` connected to `tcp://127.0.0.1` on ports `[<Port.TRANSCEIVER_SUB: 61454>]` (`0xF00E`).
# 2023-11-29 12:10:47: VERBOSE  Subscribing `sub` to: [<Topic.DL_PAYLOADS: b'\xfe\xee'>] . . .

# %%
import time
from types import SimpleNamespace
from typing import Final
from IrisBackendv3.codec.payload import EventPayload

DOWNLINK_END_EVENT_NAME: Final = 'CameraImageDownlinkComplete'
# Max amount of time since last block before we just consider the image done:
BLOCK_WAIT_TIMEOUT_SEC: Final = 5.0

if stream_via_ipc_first:
    # Mimic CLI args:
    opts = SimpleNamespace()
    opts.interp = False
    opts.debayer = False

    decoder = BasicImageDecoder.new_empty()
    decoder.FILE_PREFIX = TEST_NAME

    started: bool = False
    done: bool = False
    last_block_time_sec: float = 0
    first_block_time: float = 0
    
    # Stream file blocks into decoder:
    while not done:
        # Stream packets until done event or TIMEOUT since last file block:
        ipc_payload = manager.read('sub')
        try:
            msg = ipc.guard_msg(ipc_payload.message,
                                DownlinkedPayloadsMessage)
            payloads = msg.content.payloads
        except Exception as e:
            app.logger.error(
                f"Failed to decode IPC message `{msg}` "
                f"of `{ipc_payload=}` b/c: `{e}`."
            )
        blocks = [*payloads[FileBlockPayload]]
        if len(blocks) > 0:
            if not started:
                started = True  # we've stared to received File data
                first_block_time = time.time()
            last_block_time_sec = time.time()
        for block in payloads[FileBlockPayload]:
            block = cast(FileBlockPayload, block)
            decoder.process_file_block(block)
        
        # Check for stop condition:
        if started and len([e for e in payloads[EventPayload] if e.event.name == DOWNLINK_END_EVENT_NAME]) > 0:
            app.logger.notice(f"Finished image b/c Downlink End Event: `{DOWNLINK_END_EVENT_NAME}`.")
            done = True
        if started and (time.time() - last_block_time_sec) > BLOCK_WAIT_TIMEOUT_SEC:
            app.logger.notice(f"Finished image b/c Block Wait Timeout > {BLOCK_WAIT_TIMEOUT_SEC:.2f}s.")
            done = True

    app.logger.success(f"Image Downlinked in {time.time()-first_block_time:.3f}s.")

    # Build file memory (image build happens below):
    decoder.export_all_raw()
# Out:
# 2023-11-29 13:15:28: INFO     	1 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	2 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	3 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	4 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	5 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	6 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	7 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	8 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	9 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	10 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	11 Lines Complete . . .
# 2023-11-29 13:15:28: INFO     	12 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	13 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	14 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	15 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	16 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	17 Lines Complete . . .
# 2023-11-29 13:15:29: INFO     	18 Lines Complete . . .
# 2023-11-29 13:15:40: INFO     	269 Lines Complete . . .
# 2023-11-29 13:15:40: INFO     	270 Lines Complete . . .
# 2023-11-29 13:15:40: INFO     	271 Lines Complete . . .
# 2023-11-29 13:15:40: INFO     	272 Lines Complete . . .
# 2023-11-29 13:15:40: INFO     	273 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	274 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	275 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	276 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	277 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	278 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	279 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	280 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	281 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	282 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	283 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	284 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	285 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	286 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	287 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	288 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	289 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	290 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	291 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	292 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	293 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	294 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	295 Lines Complete . . .
# 2023-11-29 13:15:41: INFO     	296 Lines Complete . . .
# 2023-11-29 13:15:42: INFO     	297 Lines Complete . . .
# 2023-11-29 13:15:42: INFO     	298 Lines Complete . . .
# 2023-11-29 13:15:42: NOTICE   Finished image b/c Downlink End Event: `CameraImageDownlinkComplete`.
# 2023-11-29 13:15:42: SUCCESS  Image Downlinked in 13.959s.
# 2023-11-29 13:15:42: NOTICE   Saving Raw img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308 . . .
# 2023-11-29 13:15:42: INFO     	Report for Image 43308:
# 		File Group (Image) ID:	 43308,
# 		Image Valid / Internally Consistent:	 True,
# 		Image Complete:	 False,
# 		Total Image Lines:	 1944,
# 		Lines Found:	 298,
# 		Lines w/ Metadata:	 5,
# 		Lines Completed:	 298,
# 		Invalid / Internally Inconsistent Lines:	 0,
# 		Lines with Corrupted Data:	 0
# 2023-11-29 13:15:42: INFO     Assembling Image . . .
# 2023-11-29 13:15:42: INFO     Building Integer Image . . .
# 2023-11-29 13:15:42: INFO     Building Raw File . . .
# 2023-11-29 13:15:42: INFO     Building Raw Image . . .
# 2023-11-29 13:15:42: NOTICE   	Saving file report to ./out/image_file_decodings/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308.report.txt . . .
# 2023-11-29 13:15:42: NOTICE   	Saving Image pickle to ./out/image_file_decodings/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308.image.pkl . . .
# 2023-11-29 13:15:42: NOTICE   	Saving raw file to ./out/image_file_decodings/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308.raw . . .
# 2023-11-29 13:15:42: NOTICE   	Saving 1944 x 523 raw (greyscale, possibly bayered) image to ./out/image_file_decodings/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308/img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308.raw.png . . .
# 2023-11-29 13:15:42: SUCCESS  Saved img_img_EM4_SCS_MY_test_img_cam0__01HGE4P1VC8SG54TD919BKFQT7__43308.

# %%
manager.__del__() # Make sure all the IPC stuff isn't left up
# Out:
# 2023-11-29 13:15:42: NOTICE   Closing App's IPC socket(s) and context . . .

# %%
# Reload archive Pickle:
import glob
archive_ext = '.image.pkl'
test_folder = f'*{TEST_NAME}*'
archive_regex = f'./out/image_file_decodings/{test_folder}/*{archive_ext}'
image_pickle_file = glob.glob(archive_regex)[0]
with open(image_pickle_file, 'rb') as ipf:
    reloaded_img: Image = pickle.load(ipf)

# %%
# Extract notes from folder name:
image_pickle_file.split('/')[-2].replace('__', '. ').replace('_', ' ')
# Out:
# 'img img EM4 SCS MY test img cam0. 01HGE4P1VC8SG54TD919BKFQT7. 43308'

# %%
print('\n'.join(reloaded_img.report()))
# Out:
# File Group (Image) ID:	 43308
# Image Valid / Internally Consistent:	 True
# Image Complete:	 False
# Total Image Lines:	 1944
# Lines Found:	 298
# Lines w/ Metadata:	 5
# Lines Completed:	 298
# Invalid / Internally Inconsistent Lines:	 0
# Lines with Corrupted Data:	 0

# %%
# Build raw image:
lines_data = reloaded_img.assemble(equalize_lengths=True, pad_byte=b'\xAA')
lines_data_orig_copy = [x for x in lines_data]  # Copy of source to compare against
lines_arr = [[int(x) for x in l] for l in lines_data]
raw_img = np.array(lines_arr, dtype=np.uint8)
plt.figure()
plt.imshow(raw_img, cmap='gray')
plt.title('Raw Data (Flash Memory View)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import scripts.toolkit.rc11_image_toolkit as img11
import scripts.toolkit.image_compression_toolkit as ic
import PIL.Image
import time

# %%
## Build Image using Original Memory:
start_sec = time.time()
compressed_lines = reloaded_img.assemble(equalize_lengths=False)
# Decompress Flash Memory (if needed):
decompressed_lines = [ic.decompress(cl) for cl in compressed_lines if len(cl) > 0]
# Then rebuild the image from the (reconstructed) flash:
image_data = img11.extract_image_from_flash_memory(b''.join(decompressed_lines), LINE_WIDTH)
print(image_data.frame_metadata)
image = image_data.quick_build()
end_sec = time.time()
est_dl_n_processing_time = sum(len(x) for x in compressed_lines) * 3.5/243/2592*60 + (end_sec - start_sec)
plt.figure()
plt.imshow(image, cmap='gray')
plt.title(f'Image Built from Original Memory ({end_sec-start_sec:.01f}s from raw, {est_dl_n_processing_time:.1f}s to DL & Process)')
plt.show()
# Out:
# FrameMetadataRc11(fw_versions=Counter({'RC11.00.03': 1}), sensor_frame_nums=[4], interleaved_frame_nums=[3], imaging_mode=Counter({255: 1}))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Display Compression Statistics:
# Compress:
orig_size = sum(len(l) for l in decompressed_lines)
comp_size = sum(len(l) for l in compressed_lines)
# Statistics:
{
    'comp_size': f"{comp_size/1e3:.1f}kB",
    'orig_size': f"{orig_size/1e3:.1f}kB",
    'compression_factor': f"{100 * comp_size / orig_size:.1f}%",
    'downlink_time': f"{orig_size * 3.5/243/2592:.1f}min -> {comp_size * 3.5/243/2592:.1f}min",
    'equivalent_line_count': f"{orig_size/2592:.0f}lines -> {comp_size/2592:.0f}equiv.-lines"
}
# Out:
# {'comp_size': '97.1kB',
#  'orig_size': '639.5kB',
#  'compression_factor': '15.2%',
#  'downlink_time': '3.6min -> 0.5min',
#  'equivalent_line_count': '247lines -> 37equiv.-lines'}

# %%
# Histogram of compressed line lengths:
compressed_line_lengths = [len(cld) for cld in compressed_lines]
plt.figure()
plt.hist(compressed_line_lengths, bins=25)
plt.title('Histogram of Compressed Line Lengths')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pil = PIL.Image.fromarray(image.astype('uint8'), 'L').rotate(180)
pil.save(image_pickle_file.replace(".pkl", ".quick.png"))
pil
# Out:
# <PIL.Image.Image image mode=L size=3072x1944>

# %%
# Intelligently build a whole image from all valid lines in all frames:
start_sec = time.time()
full_image = image_data.smart_build()
end_sec = time.time()

plt.figure()
plt.imshow(full_image, cmap='gray')
plt.title(f'Image Assembled using All Valid Lines in All Frames ({end_sec-start_sec:.01f}s)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Median & Mean of Frame Stack:

# %%
start_sec = time.time()
median_of_frames = image_data.build_median_frame()
end_sec = time.time()

plt.figure()
plt.imshow(median_of_frames, cmap='gray')
plt.title(f"Median of All Frames ({end_sec-start_sec:.01f}s)")
plt.show()
# Out:
# /Users/connorcolombo/.pyenv/versions/3.10.8/envs/py_irisbackendv3/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## GIF of Frames (in case motion was captured):
gif_name = image_pickle_file.replace(".pkl", ".gif")
start_sec = time.time()
image_data.save_frames_gif(gif_name, rotation=180, unknown_cutoff=0.25)
end_sec = time.time()
f"GIF Build Time: {end_sec-start_sec:.01f}s"
# Out:
# 'GIF Build Time: 0.2s'

# %%
# Diplay Saved GIF (encode as b64 so it gets saved inside the notebook):
import IPython.display, base64
b64 = base64.b64encode(open(gif_name,'rb').read()).decode('ascii')
IPython.display.display(IPython.display.HTML(f'<img src="data:image/gif;base64,{b64}" />'))
# Out:
# <img src="data:image/gif;base64,..." />

# %% [markdown]
# ## Summary of Key Images:

# %% [markdown]
# ### Full "Smart Build" Interpolated Image:

# %%
full_image[np.isnan(full_image)] = 0xFF  # just in case
pil = PIL.Image.fromarray(full_image.astype('uint8'), 'L').rotate(180)
pil.save(image_pickle_file.replace(".pkl", ".interp.png"))
pil
# Out:
# <PIL.Image.Image image mode=L size=3072x1944>

# %% [markdown]
# ### Median of All (Interpolated) Frames:

# %%
pil = PIL.Image.fromarray(median_of_frames.astype('uint8'), 'L').rotate(180)
pil.save(image_pickle_file.replace(".pkl", ".median.png"))
pil
# Out:
# <PIL.Image.Image image mode=L size=3072x1944>
