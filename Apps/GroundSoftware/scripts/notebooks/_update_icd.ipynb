# %% [markdown]
# ## Temporary ICD Update Notebook
# This is to be used to update an ICD telecommand dictionary csv sheet from a previous ICD iteration (ex. from a previous PIMS test) to include any newly added commands while still preserving any definitions present in the last dictionary. This is not to be used for generating any official ICDs to be used during mission since telecommand severities and definitions may not be up-to-date (or even correct) since that's not completely necessary where these interim ICDs are needed while FSW is still flushing out its command set.
#
# Note: this only adds new command names and doesn't remove anything old since that's not necessary (an possibly undesirable) for this application.
#
# Note also: this script is really dumb and doesn't recognize when commands have simply had their names changed but are otherwise the same old commands.

# %%
# SETTINGS:
i: int = 4
last_icd_path = f'./test-data/ICD_telecommands_{i:d}.csv'
new_icd_path=f'./test-data/ICD_telecommands_{i+1:d}.csv'

# Map from column names to IDs in ICD:
start_row = 2 # index of the first row with actual data (after any sheet and column headers)
cols = {
    'opcode': 0,
    'hazard': 1,
    'yamcs_name': 2,
    'description': 3,
    'usage': 4
}

# %%
import csv

from IrisBackendv3.data_standards import DataStandards
from IrisBackendv3.data_standards.prebuilt import add_to_standards, watchdog_heartbeat_tvac
from IrisBackendv3.data_standards.logging import logger as DsLogger

# %%
DsLogger.setLevel('CRITICAL')
standards = DataStandards.build_standards()
add_to_standards(standards, watchdog_heartbeat_tvac)
standards.print_overview()
# Out:
# Data Standards Overview: [
#
# 	Module[256]::BlockDriver
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::BdCycles: uint32
#
# 		Events:
#
# 	Module[512]::RateGroupDriver
#
# 		Commands:
#
# 		Telemetry:
#
# 		Events:
#
# 	Module[768]::ActiveRateGroup-RateGroupLowFreq
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::RgMaxTime: uint32
#
# 			1.	Channel[1]::RgCycleSlips: uint32
#
# 		Events:
#
# 			0.	Event[0]::RateGroupStarted[]
#
# 			1.	Event[1]::RateGroupCycleSlip[cycle: uint32]
#
# 	Module[1024]::ActiveRateGroup-RateGroupMedFreq
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::RgMaxTime: uint32
#
# 			1.	Channel[1]::RgCycleSlips: uint32
#
# 		Events:
#
# 			0.	Event[0]::RateGroupStarted[]
#
# 			1.	Event[1]::RateGroupCycleSlip[cycle: uint32]
#
# 	Module[1280]::ActiveRateGroup-RateGroupHiFreq
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::RgMaxTime: uint32
#
# 			1.	Channel[1]::RgCycleSlips: uint32
#
# 		Events:
#
# 			0.	Event[0]::RateGroupStarted[]
#
# 			1.	Event[1]::RateGroupCycleSlip[cycle: uint32]
#
# 	Module[1536]::CubeRoverTime
#
# 		Commands:
#
# 		Telemetry:
#
# 		Events:
#
# 	Module[1792]::TlmChan
#
# 		Commands:
#
# 		Telemetry:
#
# 		Events:
#
# 	Module[2048]::CommandDispatcher
#
# 		Commands:
#
# 			0.	Command[0]::CommandDispatcher_Cmdnoop[]
#
# 			1.	Command[1]::CommandDispatcher_Cmdnoopstring[arg_1: char[40]]
#
# 			2.	Command[2]::CommandDispatcher_Cmdtestcmd1[arg_1: int32, arg_2: float, arg_3: uint8]
#
# 			3.	Command[3]::CommandDispatcher_Cmdcleartracking[]
#
# 		Telemetry:
#
# 			0.	Channel[0]::CommandsDispatched: uint32
#
# 			1.	Channel[1]::CommandErrors: uint32
#
# 		Events:
#
# 			0.	Event[0]::OpCodeRegistered[opcode: uint32, port: int32, slot: int32]
#
# 			1.	Event[1]::OpCodeDispatched[opcode: uint32, port: int32]
#
# 			2.	Event[2]::OpCodeCompleted[opcode: uint32]
#
# 			3.	Event[3]::OpCodeError[opcode: uint32, error: enum/*int32*/]
#
# 			4.	Event[4]::MalformedCommand[status: enum/*int32*/]
#
# 			5.	Event[5]::InvalidCommand[opcode: uint32]
#
# 			6.	Event[6]::TooManyCommands[opcode: uint32]
#
# 			7.	Event[7]::NoOpReceived[]
#
# 			8.	Event[8]::NoOpStringReceived[message: char[40]]
#
# 			9.	Event[9]::TestCmd1Args[arg_1: int32, arg_2: float, arg_3: uint8]
#
# 	Module[2816]::ActiveLogger
#
# 		Commands:
#
# 			0.	Command[0]::ActiveLogger_Alogseteventreportfilter[filter_level: enum/*int32*/, filter_enable: enum/*int32*/]
#
# 					Available values for `filter_level`:
#
# 						'INPUTWARNINGHI' or 0 or 0x0
#
# 						'INPUTWARNINGLO' or 1 or 0x1
#
# 						'INPUTCOMMAND' or 2 or 0x2
#
# 						'INPUTACTIVITYHI' or 3 or 0x3
#
# 						'INPUTACTIVITYLO' or 4 or 0x4
#
# 						'INPUTDIAGNOSTIC' or 5 or 0x5
#
# 					Available values for `filter_enable`:
#
# 						'INPUTENABLED' or 0 or 0x0
#
# 						'INPUTDISABLED' or 1 or 0x1
#
# 			1.	Command[1]::ActiveLogger_Alogseteventsendfilter[filter_level: enum/*int32*/, filter_enable: enum/*int32*/]
#
# 					Available values for `filter_level`:
#
# 						'SENDWARNINGHI' or 0 or 0x0
#
# 						'SENDWARNINGLO' or 1 or 0x1
#
# 						'SENDCOMMAND' or 2 or 0x2
#
# 						'SENDACTIVITYHI' or 3 or 0x3
#
# 						'SENDACTIVITYLO' or 4 or 0x4
#
# 						'SENDDIAGNOSTIC' or 5 or 0x5
#
# 					Available values for `filter_enable`:
#
# 						'SENDENABLED' or 0 or 0x0
#
# 						'SENDDISABLED' or 1 or 0x1
#
# 			2.	Command[2]::ActiveLogger_Alogdumpeventlog[filename: char[40]]
#
# 			3.	Command[3]::ActiveLogger_Alogsetidfilter[id: uint32, id_filter_enable: enum/*int32*/]
#
# 					Available values for `id_filter_enable`:
#
# 						'IDENABLED' or 0 or 0x0
#
# 						'IDDISABLED' or 1 or 0x1
#
# 			4.	Command[4]::ActiveLogger_Alogdumpfilterstate[]
#
# 		Telemetry:
#
# 		Events:
#
# 			0.	Event[0]::Alogfilewriteerr[stage: enum/*int32*/, error: int32]
#
# 			1.	Event[1]::Alogfilewritecomplete[records: uint32]
#
# 			2.	Event[2]::Alogseverityfilterstate[severity: enum/*int32*/, recv_enabled: bool, send_enabled: bool]
#
# 			3.	Event[3]::Alogidfilterenabled[id: uint32]
#
# 			4.	Event[4]::Alogidfilterlistfull[id: uint32]
#
# 			5.	Event[5]::Alogidfilterremoved[id: uint32]
#
# 			6.	Event[6]::Alogidfilternotfound[id: uint32]
#
# 	Module[4096]::WatchDogInterface
#
# 		Commands:
#
# 			0.	Command[0]::WatchDogInterface_ResetSpecific[reset_value: enum/*int32*/]
#
# 					Available values for `reset_value`:
#
# 						'NO_RESET' or 0 or 0x0
#
# 						'RESET_HERCULES' or 1 or 0x1
#
# 						'HERCULES_POWER_ON' or 2 or 0x2
#
# 						'HERCULES_POWER_OFF' or 3 or 0x3
#
# 						'RESET_RADIO' or 4 or 0x4
#
# 						'RADIO_POWER_ON' or 5 or 0x5
#
# 						'RADIO_POWER_OFF' or 6 or 0x6
#
# 						'RESET_FPGA' or 7 or 0x7
#
# 						'FPGA_POWER_ON' or 8 or 0x8
#
# 						'FPGA_POWER_OFF' or 9 or 0x9
#
# 						'RESET_MOTOR_1' or 10 or 0xa
#
# 						'RESET_MOTOR_2' or 11 or 0xb
#
# 						'RESET_MOTOR_3' or 12 or 0xc
#
# 						'RESET_MOTOR_4' or 13 or 0xd
#
# 						'RESET_ALL_MOTORS' or 14 or 0xe
#
# 						'ALL_MOTORS_ON' or 15 or 0xf
#
# 						'ALL_MOTORS_OFF' or 16 or 0x10
#
# 						'RESET_EN_3_3' or 17 or 0x11
#
# 						'EN_3_3_POWER_ON' or 18 or 0x12
#
# 						'EN_3_3_POWER_OFF' or 19 or 0x13
#
# 						'RESET_24_EN' or 20 or 0x14
#
# 						'EN_24_ON' or 21 or 0x15
#
# 						'EN_24_OFF' or 22 or 0x16
#
# 						'HDRM_OFF' or 24 or 0x18
#
# 						'FPGA_CAM_0' or 25 or 0x19
#
# 						'FPGA_CAM_1' or 26 or 0x1a
#
# 						'BATTERY_START_CHARGE' or 27 or 0x1b
#
# 						'BATTERY_STOP_CHARGE' or 28 or 0x1c
#
# 						'ENABLE_RS_422_UART' or 29 or 0x1d
#
# 						'DISABLE_RS_422_UART' or 30 or 0x1e
#
# 						'ENABLE_HEATER_CONTROL' or 31 or 0x1f
#
# 						'DISABLE_HEATER_CONTROL' or 32 or 0x20
#
# 			1.	Command[1]::WatchDogInterface_PrepareForDeployment[confirm: enum/*int32*/]
#
# 					Available values for `confirm`:
#
# 						'CONFIRM_PREP' or 96 or 0x60
#
# 			2.	Command[2]::WatchDogInterface_DisengageFromLander[confirm: enum/*int32*/]
#
# 					Available values for `confirm`:
#
# 						'CONFIRM_DEPLOY' or 96 or 0x60
#
# 			3.	Command[3]::WatchDogInterface_SwitchConnectionMode[]
#
# 			4.	Command[4]::WatchDogInterface_EngageFromLander[]
#
# 			5.	Command[170]::WatchDogInterface_SetKpSpecific[value: uint16]
#
# 			6.	Command[173]::WatchDogInterface_SetHeaterDutyCycleMax[limit: uint16]
#
# 			7.	Command[174]::WatchDogInterface_SetHeaterDutyCyclePeriod[period: uint16]
#
# 			8.	Command[175]::WatchDogInterface_SetHeaterWindow[adc_half_width: uint16]
#
# 			9.	Command[218]::WatchDogInterface_SetHeaterSetpoint[adc_setpoint: uint16]
#
# 			10.	Command[234]::WatchDogInterface_SwitchToSleepMode[confirm: enum/*int32*/]
#
# 					Available values for `confirm`:
#
# 						'CONFIRM_SLEEP' or 119 or 0x77
#
# 			11.	Command[235]::WatchDogInterface_SwitchToKeepAliveMode[confirm: enum/*int32*/]
#
# 					Available values for `confirm`:
#
# 						'CONFIRM_ALIVE' or 119 or 0x77
#
# 			12.	Command[236]::WatchDogInterface_SwitchToServiceMode[confirm: enum/*int32*/]
#
# 					Available values for `confirm`:
#
# 						'CONFIRM_SERVICE' or 119 or 0x77
#
# 		Telemetry:
#
# 			0.	Channel[2]::Voltage2.5V: int16
#
# 			1.	Channel[3]::Voltage2.8V: int16
#
# 			2.	Channel[4]::Voltage24V: int16
#
# 			3.	Channel[5]::Voltage28V: int16
#
# 			4.	Channel[16]::Batterythermistor: uint8
#
# 			5.	Channel[23]::Systemstatus: int8
#
# 			6.	Channel[24]::Batterylevel: uint16
#
# 			7.	Channel[25]::Batterycurrent: uint32
#
# 			8.	Channel[26]::Therm0: uint16
#
# 			9.	Channel[27]::Therm1: uint16
#
# 			10.	Channel[28]::Therm2: uint16
#
# 			11.	Channel[29]::Therm3: uint16
#
# 			12.	Channel[30]::Therm4: uint16
#
# 			13.	Channel[31]::Therm5: uint16
#
# 		Events:
#
# 			0.	Event[0]::WatchDogIncorrectResp[error: uint8]
#
# 			1.	Event[1]::WatchDogTimedOut[]
#
# 			2.	Event[2]::WatchDogCmdReceived[cmd: char[50]]
#
# 			3.	Event[3]::WatchDogCommError[error: uint32]
#
# 			4.	Event[4]::AdcThermistorError[]
#
# 			5.	Event[5]::WatchDogIncorrectResetValue[]
#
# 	Module[2304]::GroundInterface
#
# 		Commands:
#
# 			0.	Command[0]::GroundInterface_SetPrimaryInterface[primary_interface: enum/*int32*/]
#
# 					Available values for `primary_interface`:
#
# 						'WATCHDOG' or 0 or 0x0
#
# 						'WF_121' or 1 or 0x1
#
# 			1.	Command[1]::GroundInterface_SetGroundInterfaceTelemetryLevel[telemetry_level: enum/*int32*/]
#
# 					Available values for `telemetry_level`:
#
# 						'CRITICAL' or 0 or 0x0
#
# 						'IMPORTANT' or 1 or 0x1
#
# 						'ALL' or 2 or 0x2
#
# 		Telemetry:
#
# 			0.	Channel[0]::GiUplinkSeqNum: uint8
#
# 			1.	Channel[1]::GiDownlinkSeqNum: uint8
#
# 			2.	Channel[2]::GiPacketsReceived: uint32
#
# 			3.	Channel[3]::GiPacketsTransmitted: uint32
#
# 			4.	Channel[4]::GiTlmItemsReceived: uint32
#
# 			5.	Channel[5]::GiTlmItemsDownlinked: uint32
#
# 			6.	Channel[6]::GiLogsReceived: uint32
#
# 			7.	Channel[7]::GiLogsDownlinked: uint32
#
# 			8.	Channel[8]::GiCmdsUplinked: uint32
#
# 			9.	Channel[9]::GiCmdsSent: uint32
#
# 			10.	Channel[10]::GiUplinkPktErrs: uint32
#
# 			11.	Channel[11]::GiAppBytesReceived: uint32
#
# 			12.	Channel[12]::GiAppBytesDownlinked: uint32
#
# 		Events:
#
# 			0.	Event[0]::GiUplinkedPacketError[error_type: enum/*int32*/, expected: uint16, got: uint16]
#
# 			1.	Event[1]::GiCommandReceived[seq: uint8, checksum: uint16]
#
# 			2.	Event[2]::GiDownlinkedPacket[seq: uint8, checksum: uint16, length: uint16]
#
# 			3.	Event[3]::GiDownlinkedItem[seq: uint8, from: enum/*int32*/]
#
# 	Module[2560]::NetworkManager
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::Rssi: int8
#
# 			1.	Channel[1]::Snr: int8
#
# 			2.	Channel[2]::PktRecv: uint32
#
# 			3.	Channel[3]::PktSent: uint32
#
# 		Events:
#
# 			0.	Event[0]::StateChange[from_state: enum/*int32*/, to_state: enum/*int32*/]
#
# 			1.	Event[1]::ExecuteCallbackError[error_code: uint16]
#
# 			2.	Event[2]::Wf121InitializationFailed[]
#
# 	Module[3840]::Imu
#
# 		Commands:
#
# 			0.	Command[0]::Imu_ImuReportData[]
#
# 			1.	Command[1]::Imu_ImuTurnOn[]
#
# 			2.	Command[2]::Imu_ImuTurnOff[]
#
# 		Telemetry:
#
# 			0.	Channel[0]::XAcc: int16
#
# 			1.	Channel[1]::YAcc: int16
#
# 			2.	Channel[2]::ZAcc: int16
#
# 			3.	Channel[3]::XAng: uint16
#
# 			4.	Channel[4]::YAng: uint16
#
# 			5.	Channel[5]::ZAng: uint16
#
# 		Events:
#
# 			0.	Event[0]::ImuAngleWarning[]
#
# 			1.	Event[1]::ImuCommunicationFailure[]
#
# 			2.	Event[2]::ImuPoweredOn[]
#
# 			3.	Event[3]::ImuPoweredOff[]
#
# 	Module[3584]::MotorControl
#
# 		Commands:
#
# 			0.	Command[0]::MotorControl_McCurrentPid[motor_id: uint8, pi_values: uint32]
#
# 			1.	Command[1]::MotorControl_McSpeedPid[motor_id: uint8, pid_values: uint32]
#
# 			2.	Command[3]::MotorControl_McAcceleration[motor_id: uint8, rate_values: uint32]
#
# 			3.	Command[4]::MotorControl_McStallDetection[motor_id: uint8, value: uint8]
#
# 			4.	Command[5]::MotorControl_McResetPosition[motor_id: uint8]
#
# 			5.	Command[6]::MotorControl_McSpin[motor_id: uint8, raw_ticks: uint32]
#
# 			6.	Command[7]::MotorControl_McPowerBoost[motor_id: uint8, value: uint8]
#
# 			7.	Command[8]::MotorControl_McSetParameter[param_select: enum/*int32*/, new_value: uint32]
#
# 					Available values for `param_select`:
#
# 						'MC_PARAM_1' or 0 or 0x0
#
# 						'MC_PARAM_2' or 1 or 0x1
#
# 			8.	Command[16]::MotorControl_McUpdateTelemetry[]
#
# 		Telemetry:
#
# 			0.	Channel[0]::McflEncoderTicks: int32
#
# 			1.	Channel[1]::McflCurrent: uint16
#
# 			2.	Channel[3]::McfrEncoderTicks: int32
#
# 			3.	Channel[4]::McfrCurrent: uint16
#
# 			4.	Channel[6]::McrrEncoderTicks: int32
#
# 			5.	Channel[7]::McrrCurrent: uint16
#
# 			6.	Channel[9]::McrlEncoderTicks: int32
#
# 			7.	Channel[10]::McrlCurrent: uint16
#
# 			8.	Channel[11]::McflStatus: uint8
#
# 			9.	Channel[12]::McfrStatus: uint8
#
# 			10.	Channel[13]::McrrStatus: uint8
#
# 			11.	Channel[14]::McrlStatus: uint8
#
# 		Events:
#
# 			0.	Event[0]::McMoveStarted[]
#
# 			1.	Event[1]::McMoveComplete[]
#
# 			2.	Event[2]::McmspFaultDetected[]
#
# 			3.	Event[3]::McmspNotResponding[]
#
# 			4.	Event[4]::McmspNotReporting[]
#
# 			5.	Event[5]::McParameterChanged[]
#
# 			6.	Event[6]::McEncoderReset[]
#
# 	Module[3328]::Navigation
#
# 		Commands:
#
# 			0.	Command[0]::Navigation_NavDriveForward[distance: uint8, speed: uint8, callback_id: uint16]
#
# 			1.	Command[1]::Navigation_NavDriveBackwards[distance: uint8, speed: uint8, callback_id: uint16]
#
# 			2.	Command[2]::Navigation_NavRotateRight[distance: uint8, speed: uint8, callback_id: uint16]
#
# 			3.	Command[3]::Navigation_NavRotateLeft[distance: uint8, speed: uint8, callback_id: uint16]
#
# 			4.	Command[4]::Navigation_NavStopMovement[]
#
# 		Telemetry:
#
# 			0.	Channel[0]::NavMovedForward: uint16
#
# 			1.	Channel[1]::NavMovedBackward: uint16
#
# 			2.	Channel[2]::NavTurnedLeft: uint16
#
# 			3.	Channel[3]::NavTurnedRight: uint16
#
# 			4.	Channel[4]::NavImageSize: uint16
#
# 		Events:
#
# 			0.	Event[0]::NavMoveInterrupted[]
#
# 			1.	Event[1]::NavMoveQueueLimit[]
#
# 	Module[4352]::Camera
#
# 		Commands:
#
# 			0.	Command[0]::Camera_GetStatus[]
#
# 			1.	Command[1]::Camera_TakeImage[camera_num: uint8, callback_id: uint16]
#
# 			2.	Command[2]::Camera_Error[action: uint8]
#
# 			3.	Command[3]::Camera_ConfigureCamera0[config: uint64]
#
# 			4.	Command[4]::Camera_Camera0Crop[config: uint64]
#
# 			5.	Command[5]::Camera_ConfigureCamera1[config: uint64]
#
# 			6.	Command[6]::Camera_Camera1Crop[config: uint64]
#
# 			7.	Command[7]::Camera_ReadImage[callback_id: uint16]
#
# 			8.	Command[8]::Camera_EraseImage[]
#
# 			9.	Command[9]::Camera_SoftCameraReset[camera_num: uint8]
#
# 			10.	Command[10]::Camera_ImageDump[]
#
# 		Telemetry:
#
# 			0.	Channel[0]::CamComponentImagesRequested: uint32
#
# 			1.	Channel[1]::CamCommandImagesRequested: uint32
#
# 			2.	Channel[2]::CamImagesSent: uint32
#
# 			3.	Channel[3]::CamBytesSent: uint32
#
# 			4.	Channel[4]::CamLatestCallbackId: uint16
#
# 		Events:
#
# 	Module[65280]::WatchdogHeartbeatTvac
#
# 		Commands:
#
# 		Telemetry:
#
# 			0.	Channel[0]::AdcTempRaw: uint16
#
# 			1.	Channel[1]::AdcTempKelvin: double
#
# 			2.	Channel[16]::ChargeRaw: uint16
#
# 			3.	Channel[17]::ChargeMah: double
#
# 			4.	Channel[32]::VoltageRaw: uint16
#
# 			5.	Channel[33]::Voltage: double
#
# 			6.	Channel[48]::CurrentRaw: uint16
#
# 			7.	Channel[49]::CurrentAmps: double
#
# 			8.	Channel[64]::FuelTempRaw: uint16
#
# 			9.	Channel[65]::FuelTempKelvin: double
#
# 			10.	Channel[80]::KpHeater: uint16
#
# 			11.	Channel[81]::HeaterSetpoint: uint16
#
# 			12.	Channel[82]::HeaterSetpointKelvin: uint16
#
# 			13.	Channel[83]::HeaterWindow: uint16
#
# 			14.	Channel[84]::HeaterWindowKelvin: uint16
#
# 			15.	Channel[85]::HeaterPwmLimit: uint16
#
# 			16.	Channel[86]::WatchdogMode: enum/*int32*/
#
# 			17.	Channel[87]::HeaterStatus: uint8
#
# 			18.	Channel[88]::HeatingControlEnabled: uint8
#
# 			19.	Channel[89]::HeaterPwmDutyCycle: uint16
#
# 		Events:
#
# ]

# %%
# Load last ICD:
icd = []
with open(last_icd_path, mode='r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        icd.append(row)

# %%
# Grab all commands from ICD:
old_cmds = [(entry[cols['opcode']].lower(), entry[cols['yamcs_name']]) for entry in icd[start_row:] if entry[cols['yamcs_name']] != '']

# Grab all commands in the latest data standards:
current_cmds = [(f'0x{(mid | c.ID):04x}', n) for n, (mid, c) in standards.commands_chainmap_name.items()]
# Double up all commands (like in icd):
current_cmds = [x for op,n in current_cmds for x in ((op, n+'_wired'), (op, n+'_wifi'))]


# Grab list of all new command names (in current standards but not the old list):
new_cmds = [(op,n) for (op,n) in current_cmds if n not in [n for _,n in old_cmds]]


# Also check if there are any old commands with a mismatched opcodes:
bad_ops = [(op,n) for (op,n) in current_cmds if (op,n) not in new_cmds and (op,n) not in old_cmds]
bad_ops = [([old_op for (old_op,no) in old_cmds if no == n][0], new_op, n) for (new_op,n) in bad_ops]
if len(bad_ops) > 1:
    print("NOTE: The following opcodes have changed (old_op, current_op, n). The current (latest) opcodes will be used.")
    print(bad_ops)

# %%
# Update old command opcodes in ICD:
for (_, new_op, n) in bad_ops:
    i, row = [(i, row) for (i, row) in enumerate(icd) if row[cols['yamcs_name']] == n][0]
    row[cols['opcode']] = new_op
    icd[i] = row

# Append all newly added commands to icd:
for opcode, name in new_cmds:
    # Create an empty set of columns:
    entry = [''] * len(cols)
    # Populate relevant columns:
    entry[cols['opcode']] = opcode
    entry[cols['yamcs_name']] = name
    icd.append(entry)

# %%
# Write out the new ICD:
with open(new_icd_path, mode='w') as f:
    writer = csv.writer(f, delimiter=',', quotechar='"')
    for row in icd:
        writer.writerow(row)
